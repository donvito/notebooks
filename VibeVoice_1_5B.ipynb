# %% [markdown]
# <a href="https://colab.research.google.com/github/donvito/colab-notebooks/blob/main/VibeVoice_1_5B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/microsoft/VibeVoice-1.5B
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/microsoft/VibeVoice-1.5B)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-to-speech", model="microsoft/VibeVoice-1.5B")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1359             try:
# -> 1360                 config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1361             except KeyError:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in __getitem__(self, key)
#    1047         if key not in self._mapping:
# -> 1048             raise KeyError(key)
#    1049         value = self._mapping[key]
#
# KeyError: 'vibevoice'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3190993759.py in <cell line: 0>()
# ...

# %%
# Load model directly
from transformers import AutoModelForSeq2SeqLM
model = AutoModelForSeq2SeqLM.from_pretrained("microsoft/VibeVoice-1.5B", dtype="auto")
